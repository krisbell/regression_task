# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.weightstats import _tconfint_generic

# Warehouse and Retail Sales dataset
# https://data.montgomerycountymd.gov/Community-Recreation/Warehouse-and-Retail-Sales/v76h-r7br
# https://data.world/montgomery-county-of-maryland/3267757c-1b3f-4eb6-8c8c-dce7bb855e44

# STORE_SALES - Cases of product sold to MC licensees 
# SALES - Cases of product sold from DLC dispensaries

# %%
params = {'figure.figsize': (15,7),
          'font.size': 14,
         }
plt.rcParams.update(params)

# %%
data = pd.read_csv('./data/data_regression_for_task.csv')
print('Размерность данных', data.shape)
# Out:
# Размерность данных (128355, 8)

# %%
data.head()
# Out:
#    YEAR  MONTH                    CONTRAGENT ARTICLE_CODE  \
# 0  2017      4               ROYAL WINE CORP       100200
# 1  2017      4      SANTA MARGHERITA USA INC       100749
# 2  2017      4            JIM BEAM BRANDS CO        10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC        10120
# 4  2017      4               ROYAL WINE CORP       101664
#
#                             ARTICLE_NAME ARTICLE_GROUP  SALES  STORE_SALES
# 0                      GAMLA CAB - 750ML          WINE    0.0          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML          WINE    0.0          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML        LIQUOR    0.0          0.0
# 3          J W DANT BOURBON 100P - 1.75L        LIQUOR    0.0          0.0
# 4            RAMON CORDOVA RIOJA - 750ML          WINE    0.0          0.0

# %% [markdown]
# Датасет содержит информацию о продажах алкогольной продукции по месяцам.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128355 entries, 0 to 128354
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   YEAR           128355 non-null  int64
#  1   MONTH          128355 non-null  int64
#  2   CONTRAGENT     128331 non-null  object
#  3   ARTICLE_CODE   128355 non-null  object
#  4   ARTICLE_NAME   128355 non-null  object
#  5   ARTICLE_GROUP  128354 non-null  object
#  6   SALES          128355 non-null  float64
#  7   STORE_SALES    128355 non-null  float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 7.8+ MB

# %% [markdown]
# Типы представленных данных: int64, float64, object. Так как SALES, STORE_SALES скорее всего означают количество проданных товаров, преобразуем их к типу int.

# %%
data['SALES'] = data['SALES'].astype('int64')
data['STORE_SALES'] = data['STORE_SALES'].astype('int64')

# %% [markdown]
# Есть пропуски в столбцах CONTRAGENT, ARTICLE_GROUP, но их немного < 1%. Посмотрим на эти строки

# %%
data.count()*100/len(data)
# Out:
# YEAR             100.000000
# MONTH            100.000000
# CONTRAGENT        99.981302
# ARTICLE_CODE     100.000000
# ARTICLE_NAME     100.000000
# ARTICLE_GROUP     99.999221
# SALES            100.000000
# STORE_SALES      100.000000
# dtype: float64

# %% [markdown]
# Пропуск значения в ARTICLE_GROUP есть только в одной строке. И в данных больше не упоминаются продажи этого товара. Не сложно выяснить, что этот товар относится к группе "WINE".

# %%
data[data['ARTICLE_GROUP'].isnull()]
# Out:
#        YEAR  MONTH                         CONTRAGENT ARTICLE_CODE  \
# 66439  2017     10  REPUBLIC NATIONAL DISTRIBUTING CO       347939
#
#                                    ARTICLE_NAME ARTICLE_GROUP  SALES  \
# 66439  FONTANAFREDDA BAROLO SILVER LABEL 750 ML           NaN      0
#
#        STORE_SALES
# 66439            1

# %%
print('Строк с наименованием "FONTANAFREDDA BAROLO SILVER LABEL 750 ML": {}'.format(
      data[data['ARTICLE_NAME'] == 'FONTANAFREDDA BAROLO SILVER LABEL 750 ML'].shape[0]))
print('Строк с артикулом "347939": {}'.format(
      data[data['ARTICLE_CODE'] == '347939'].shape[0]))
# Out:
# Строк с наименованием "FONTANAFREDDA BAROLO SILVER LABEL 750 ML": 1
# Строк с артикулом "347939": 1

# %%
data.loc[data['ARTICLE_GROUP'].isnull(),'ARTICLE_GROUP'] = 'WINE'

# %% [markdown]
# Пропуск значения в CONTRAGENT есть только в 24 строках. В них присутствуют отрицательные значения STORE_SALES и только нулевые значнения SALES. При этом видим странные артикулы товаров: BEER CREDIT, WINE CREDIT, EMPTY WINE KEG - KEGS. Больше в данных не встречаются записи о BEER CREDIT, WINE CREDIT, EMPTY WINE KEG - KEGS.
#
# Можно исключить такие записи, так они не будут информативны для предсказания обычных продаж.

# %%
print('Число пропусков CONTRAGENT: {}'.format(data[data['CONTRAGENT'].isnull()].shape[0]))
data[data['CONTRAGENT'].isnull()]
# Out:
# Число пропусков CONTRAGENT: 24
#         YEAR  MONTH CONTRAGENT ARTICLE_CODE           ARTICLE_NAME  \
# 19483   2017      6        NaN         1279  EMPTY WINE KEG - KEGS
# 20056   2017      8        NaN         1279  EMPTY WINE KEG - KEGS
# 32282   2017      6        NaN           BC            BEER CREDIT
# 32283   2017      6        NaN           WC            WINE CREDIT
# 45871   2017      8        NaN           BC            BEER CREDIT
# 45872   2017      8        NaN           WC            WINE CREDIT
# 46518   2017      9        NaN         1279  EMPTY WINE KEG - KEGS
# 59259   2017      9        NaN           BC            BEER CREDIT
# 59260   2017      9        NaN           WC            WINE CREDIT
# 59920   2017     10        NaN         1279  EMPTY WINE KEG - KEGS
# 72878   2017     10        NaN           BC            BEER CREDIT
# 72879   2017     10        NaN           WC            WINE CREDIT
# 73546   2017     11        NaN         1279  EMPTY WINE KEG - KEGS
# 87410   2017     11        NaN           BC            BEER CREDIT
# 87411   2017     11        NaN           WC            WINE CREDIT
# 88078   2017     12        NaN         1279  EMPTY WINE KEG - KEGS
# 101909  2017     12        NaN           BC            BEER CREDIT
# 101910  2017     12        NaN           WC            WINE CREDIT
# 102542  2018      1        NaN         1279  EMPTY WINE KEG - KEGS
# 115254  2018      1        NaN           BC            BEER CREDIT
# 115255  2018      1        NaN           WC            WINE CREDIT
# 115874  2018      2        NaN         1279  EMPTY WINE KEG - KEGS
# 128353  2018      2        NaN           BC            BEER CREDIT
# 128354  2018      2        NaN           WC            WINE CREDIT
#
#        ARTICLE_GROUP  SALES  STORE_SALES
# 19483        DUNNAGE      0           -9
# 20056        DUNNAGE      0           -5
# 32282            REF      0          -58
# 32283            REF      0           -8
# 45871            REF      0         -699
# 45872            REF      0           -5
# 46518        DUNNAGE      0           -9
# 59259            REF      0         -502
# 59260            REF      0          -15
# 59920        DUNNAGE      0           -6
# 72878            REF      0        -1308
# 72879            REF      0          -21
# 73546        DUNNAGE      0           -5
# 87410            REF      0        -1755
# 87411            REF      0         -375
# 88078        DUNNAGE      0           -8
# 101909           REF      0        -1644
# 101910           REF      0         -156
# 102542       DUNNAGE      0          -11
# 115254           REF      0          -21
# 115255           REF      0          -71
# 115874       DUNNAGE      0           -3
# 128353           REF      0          -35
# 128354           REF      0          -81

# %%
print('Строк с наименованием "EMPTY WINE KEG - KEGS": {}'.format(
      data[data['ARTICLE_NAME'] == 'EMPTY WINE KEG - KEGS'].shape[0]))
print('Cтрок с артикулом "1279": {}'.format(
      data[data['ARTICLE_CODE'] == '1279'].shape[0]))

print('Строк с наименованием "BEER CREDIT": {}'.format(
      data[data['ARTICLE_NAME'] == 'BEER CREDIT'].shape[0]))
print('Cтрок с артикулом "BC": {}'.format(
      data[data['ARTICLE_CODE'] == 'BC'].shape[0]))

print('Строк с наименованием "WINE CREDIT": {}'.format(
      data[data['ARTICLE_NAME'] == 'WINE CREDIT'].shape[0]))
print('Cтрок с артикулом "WC": {}'.format(
      data[data['ARTICLE_CODE'] == 'WC'].shape[0]))
# Out:
# Строк с наименованием "EMPTY WINE KEG - KEGS": 8
# Cтрок с артикулом "1279": 8
# Строк с наименованием "BEER CREDIT": 8
# Cтрок с артикулом "BC": 8
# Строк с наименованием "WINE CREDIT": 8
# Cтрок с артикулом "WC": 8

# %% [markdown]
# Посмотрим какие данные содержатся для группы DUNNAGE: пустые кеги, нулевые продажи. Удалим эту группу.

# %%
data.loc[data['ARTICLE_GROUP'] == 'DUNNAGE', 'ARTICLE_NAME'].unique()
# Out:
# array(['EMPTY WINE KEG - KEGS', 'EMPTY 1/2 KEG (30.00)',
#        'EMPTY 1/6 KEG (30.00)', 'EMPTY 1/4 KEG (30.00)'], dtype=object)

# %%
data.loc[data['ARTICLE_GROUP'] == 'DUNNAGE','CONTRAGENT'].unique()
# Out:
# array([nan, 'ANHEUSER BUSCH INC'], dtype=object)

# %%
data.loc[(data['CONTRAGENT'] == 'ANHEUSER BUSCH INC')&
         (data['STORE_SALES']<0)]
# Out:
#         YEAR  MONTH          CONTRAGENT ARTICLE_CODE  \
# 19863   2017      6  ANHEUSER BUSCH INC          175
# 20102   2017      6  ANHEUSER BUSCH INC          205
# 21036   2017      6  ANHEUSER BUSCH INC        25942
# 21128   2017      6  ANHEUSER BUSCH INC          264
# 33435   2017      8  ANHEUSER BUSCH INC          175
# 33696   2017      8  ANHEUSER BUSCH INC          205
# 34601   2017      8  ANHEUSER BUSCH INC        25533
# 34766   2017      8  ANHEUSER BUSCH INC          264
# 47004   2017      9  ANHEUSER BUSCH INC          175
# 47259   2017      9  ANHEUSER BUSCH INC          205
# 48336   2017      9  ANHEUSER BUSCH INC          264
# 60378   2017     10  ANHEUSER BUSCH INC          175
# 60629   2017     10  ANHEUSER BUSCH INC          205
# 61776   2017     10  ANHEUSER BUSCH INC          264
# 69859   2017     10  ANHEUSER BUSCH INC        70593
# 74016   2017     11  ANHEUSER BUSCH INC          175
# 74283   2017     11  ANHEUSER BUSCH INC          205
# 75495   2017     11  ANHEUSER BUSCH INC          264
# 84333   2017     11  ANHEUSER BUSCH INC        70593
# 88537   2017     12  ANHEUSER BUSCH INC          175
# 88802   2017     12  ANHEUSER BUSCH INC          205
# 90004   2017     12  ANHEUSER BUSCH INC          264
# 102952  2018      1  ANHEUSER BUSCH INC          175
# 103208  2018      1  ANHEUSER BUSCH INC          205
# 104278  2018      1  ANHEUSER BUSCH INC          264
# 104516  2018      1  ANHEUSER BUSCH INC        28400
# 104589  2018      1  ANHEUSER BUSCH INC        28652
# 116298  2018      2  ANHEUSER BUSCH INC          175
# 116542  2018      2  ANHEUSER BUSCH INC          205
# 117617  2018      2  ANHEUSER BUSCH INC          264
# 117928  2018      2  ANHEUSER BUSCH INC        28735
#
#                                   ARTICLE_NAME ARTICLE_GROUP  SALES  \
# 19863                    EMPTY 1/2 KEG (30.00)       DUNNAGE      0
# 20102                    EMPTY 1/6 KEG (30.00)       DUNNAGE      0
# 21036              REDHOOK BLACKHOOK 1/6TH KEG          KEGS      0
# 21128                    EMPTY 1/4 KEG (30.00)       DUNNAGE      0
# 33435                    EMPTY 1/2 KEG (30.00)       DUNNAGE      0
# 33696                    EMPTY 1/6 KEG (30.00)       DUNNAGE      0
# 34601               SHOCK TOP RUBY FRESH 1/6KG          KEGS      0
# 34766                    EMPTY 1/4 KEG (30.00)       DUNNAGE      0
# 47004                    EMPTY 1/2 KEG (30.00)       DUNNAGE      0
# 47259                    EMPTY 1/6 KEG (30.00)       DUNNAGE      0
# 48336                    EMPTY 1/4 KEG (30.00)       DUNNAGE      0
# 60378                    EMPTY 1/2 KEG (30.00)       DUNNAGE      0
# 60629                    EMPTY 1/6 KEG (30.00)       DUNNAGE      0
# 61776                    EMPTY 1/4 KEG (30.00)       DUNNAGE      0
# 69859                ELYSIAN SUPERFUZZ 1/2 KEG          KEGS      0
# 74016                    EMPTY 1/2 KEG (30.00)       DUNNAGE      0
# 74283                    EMPTY 1/6 KEG (30.00)       DUNNAGE      0
# 75495                    EMPTY 1/4 KEG (30.00)       DUNNAGE      0
# 84333                ELYSIAN SUPERFUZZ 1/2 KEG          KEGS      0
# 88537                    EMPTY 1/2 KEG (30.00)       DUNNAGE      0
# 88802                    EMPTY 1/6 KEG (30.00)       DUNNAGE      0
# 90004                    EMPTY 1/4 KEG (30.00)       DUNNAGE      0
# 102952                   EMPTY 1/2 KEG (30.00)       DUNNAGE      0
# 103208                   EMPTY 1/6 KEG (30.00)       DUNNAGE      0
# 104278                   EMPTY 1/4 KEG (30.00)       DUNNAGE      0
# 104516  GOOSE ISLAND FLIGHT PACK SMPLR 12PK NR          BEER      0
# 104589              BEST DAMN ROOT BEER 4/6 NR          BEER   1250
# 116298                   EMPTY 1/2 KEG (30.00)       DUNNAGE      0
# 116542                   EMPTY 1/6 KEG (30.00)       DUNNAGE      0
# 117617                   EMPTY 1/4 KEG (30.00)       DUNNAGE      0
# 117928           GOOSE ISLAND FEST BIER 1/2 KG          KEGS      0
#
#         STORE_SALES
# 19863         -4804
# 20102         -1208
# 21036            -1
# 21128          -363
# 33435         -4536
# 33696         -1068
# 34601            -1
# 34766          -331
# 47004         -4210
# 47259         -1008
# 48336          -308
# 60378         -4996
# 60629         -1238
# 61776          -365
# 69859            -1
# 74016         -4312
# 74283         -1007
# 75495          -286
# 84333            -3
# 88537         -3688
# 88802          -925
# 90004          -271
# 102952        -4302
# 103208         -973
# 104278         -337
# 104516           -1
# 104589           -1
# 116298        -3666
# 116542         -821
# 117617         -252
# 117928           -1

# %%
data[data['ARTICLE_GROUP'] == 'DUNNAGE'].describe()
# Out:
#               YEAR      MONTH  SALES  STORE_SALES
# count    32.000000  32.000000   32.0    32.000000
# mean   2017.250000   7.375000    0.0 -1416.593750
# std       0.439941   3.866732    0.0  1757.058353
# min    2017.000000   1.000000    0.0 -4996.000000
# 25%    2017.000000   5.000000    0.0 -1845.000000
# 50%    2017.000000   8.500000    0.0  -593.000000
# 75%    2017.250000  10.250000    0.0  -191.750000
# max    2018.000000  12.000000    0.0    -3.000000

# %%
data.drop(data[data['ARTICLE_GROUP'] == 'DUNNAGE'].index, inplace=True)

# %% [markdown]
# Теперь посмотрим на категорию REF. Там, где BEER CREDIT и WINE CREDIT, SALES = 0 (эти записи удалим).

# %%
data[data['ARTICLE_GROUP'] == 'REF'][:10]
# Out:
#        YEAR  MONTH CONTRAGENT ARTICLE_CODE                       ARTICLE_NAME  \
# 111    2017      4    Default          112                          CORKSCREW
# 2913   2017     10    Default        59978           STORE SPECIAL BEER QUART
# 18994  2017      6    Default          112                          CORKSCREW
# 28632  2017      6    Default        59668  STORE SPECIAL WINE 355 ML - 355ML
# 28634  2017      6    Default        59781  STORE SPECIAL WINE 750 ML - 750ML
# 32282  2017      6        NaN           BC                        BEER CREDIT
# 32283  2017      6        NaN           WC                        WINE CREDIT
# 32576  2017      8    Default          112                          CORKSCREW
# 33165  2017      8    Default          140             WINE AERATOR-IN BOTTLE
# 42287  2017      8    Default        59781  STORE SPECIAL WINE 750 ML - 750ML
#
#       ARTICLE_GROUP  SALES  STORE_SALES
# 111             REF      0            0
# 2913            REF    250            0
# 18994           REF  20400            0
# 28632           REF   8550            0
# 28634           REF   1650            0
# 32282           REF      0          -58
# 32283           REF      0           -8
# 32576           REF  19300            0
# 33165           REF    160            0
# 42287           REF     80            0

# %%
data.drop(data[data['CONTRAGENT'].isnull()].index, inplace=True)
data.shape
# Out:
# (128307, 8)

# %%
data.nunique()
# Out:
# YEAR                 2
# MONTH               10
# CONTRAGENT         333
# ARTICLE_CODE     23550
# ARTICLE_NAME     23618
# ARTICLE_GROUP        7
# SALES             7019
# STORE_SALES       1230
# dtype: int64

# %% [markdown]
# Числа уникальных значений для ARTICLE_CODE и ARTICLE_NAME не совпадают. Уникальных ARTICLE_NAME немного больше. Посмотрим на артикулы, для которых присуствуют несколько наименований. В наименованиях есть незначительные различия. Сделаем так чтобы каждому коду соответствовало только одно название (возьмем первое встречающееся название для каждого кода).

# %%
count_names = data.groupby('ARTICLE_CODE')['ARTICLE_NAME'].nunique()
codes = count_names[count_names > 1].index
data.loc[data['ARTICLE_CODE'].isin(codes),
         ['ARTICLE_CODE','ARTICLE_NAME']].drop_duplicates().sort_values(['ARTICLE_CODE']).head(10)
# Out:
#        ARTICLE_CODE                               ARTICLE_NAME
# 39            10444    JAMESON IRISH WHISKY CASK MATES - 750ML
# 102004        10444            JAMESON CASKMATES STOUT - 750ML
# 72981         10491           SAVE ME SF MARRY ME ROSE - 750ML
# 5304          10491                 SMSF MARRY ME ROSE - 750ML
# 52            10636               HAKUSHU WHISKY 12 YR - 750ML
# 115390        10636              HAKUSHU WHISKEY 12 YR - 750ML
# 59531         11088  EVAN WILLIAMS BLACK SOUR MASH 7YR - 750ML
# 107           11088     E WILLIAMS BLACK SOUR MASH 7YR - 750ML
# 5525          11373            THE POGUES IRISH WHISKY - 750ML
# 115559        11373           THE POGUES IRISH WHISKEY - 750ML

# %%
count_names = data.groupby('ARTICLE_CODE')['ARTICLE_NAME'].unique()
count_names = dict(count_names.apply(lambda x: x[0]))
data['ARTICLE_NAME'] = data['ARTICLE_CODE'].map(count_names)

# %%
data[['ARTICLE_CODE','ARTICLE_NAME']].nunique()
# Out:
# ARTICLE_CODE    23550
# ARTICLE_NAME    23413
# dtype: int64

# %% [markdown]
# Далее посмотрим на те наименования, у которых есть неколько артикулов. Присутствуют строки, где совпадают YEAR, MONTH, CONTRAGENT, ARTICLE_NAME, ARTICLE_GROUP но различаются SALES и STORE_SALES. Сгруппируем такие строки, просуммировав продажи.
#
# Будем в дальнейшем отождествлять товар с его название, а не артикулом.
#
# В названиях присутствует потенциально полезная информация об объеме, виде напитка. Можно попробовать ее извлечь.

# %%
count_codes = data.groupby('ARTICLE_NAME')['ARTICLE_CODE'].nunique()
names = count_codes[count_codes > 1].index
data.loc[data['ARTICLE_NAME'].isin(names),['YEAR', 'MONTH', 'CONTRAGENT',
        'ARTICLE_CODE','ARTICLE_NAME','ARTICLE_GROUP', 'SALES', 'STORE_SALES']
        ].drop_duplicates().sort_values(['ARTICLE_NAME','YEAR','MONTH'])[:20]
# Out:
#         YEAR  MONTH                         CONTRAGENT ARTICLE_CODE  \
# 2522    2017      4  REPUBLIC NATIONAL DISTRIBUTING CO        44916
# 14184   2017      5  REPUBLIC NATIONAL DISTRIBUTING CO        44916
# 27700   2017      6  REPUBLIC NATIONAL DISTRIBUTING CO        44916
# 33560   2017      8  REPUBLIC NATIONAL DISTRIBUTING CO       189405
# 41367   2017      8  REPUBLIC NATIONAL DISTRIBUTING CO        44916
# 54722   2017      9  REPUBLIC NATIONAL DISTRIBUTING CO        44916
# 60494   2017     10  REPUBLIC NATIONAL DISTRIBUTING CO       189405
# 68236   2017     10  REPUBLIC NATIONAL DISTRIBUTING CO        44916
# 82530   2017     11  REPUBLIC NATIONAL DISTRIBUTING CO        44916
# 96999   2017     12  REPUBLIC NATIONAL DISTRIBUTING CO        44916
# 110589  2018      1  REPUBLIC NATIONAL DISTRIBUTING CO        44916
# 123643  2018      2  REPUBLIC NATIONAL DISTRIBUTING CO        44916
# 13167   2017      5                ELITE WINES IMPORTS       406961
# 26730   2017      6                ELITE WINES IMPORTS       406961
# 34222   2017      8                ELITE WINES IMPORTS       233914
# 40394   2017      8                ELITE WINES IMPORTS       406961
# 47745   2017      9                ELITE WINES IMPORTS       233914
# 53775   2017      9                ELITE WINES IMPORTS       406961
# 61121   2017     10                ELITE WINES IMPORTS       233914
# 74811   2017     11                ELITE WINES IMPORTS       233914
#
#                                 ARTICLE_NAME ARTICLE_GROUP  SALES  STORE_SALES
# 2522        A TO Z WILLAMETTE P/GRIS - 750ML          WINE      0            0
# 14184       A TO Z WILLAMETTE P/GRIS - 750ML          WINE  11820            2
# 27700       A TO Z WILLAMETTE P/GRIS - 750ML          WINE   7860            5
# 33560       A TO Z WILLAMETTE P/GRIS - 750ML          WINE      0            2
# 41367       A TO Z WILLAMETTE P/GRIS - 750ML          WINE   8750            8
# 54722       A TO Z WILLAMETTE P/GRIS - 750ML          WINE  10650            7
# 60494       A TO Z WILLAMETTE P/GRIS - 750ML          WINE      0            1
# 68236       A TO Z WILLAMETTE P/GRIS - 750ML          WINE   8070            8
# 82530       A TO Z WILLAMETTE P/GRIS - 750ML          WINE  15220            6
# 96999       A TO Z WILLAMETTE P/GRIS - 750ML          WINE  18050            7
# 110589      A TO Z WILLAMETTE P/GRIS - 750ML          WINE  12230            4
# 123643      A TO Z WILLAMETTE P/GRIS - 750ML          WINE  11930            7
# 13167   ABADAL CAB FRANC TEMPRANILLO - 750ML          WINE      0            3
# 26730   ABADAL CAB FRANC TEMPRANILLO - 750ML          WINE    170           10
# 34222   ABADAL CAB FRANC TEMPRANILLO - 750ML          WINE      0            1
# 40394   ABADAL CAB FRANC TEMPRANILLO - 750ML          WINE      0            1
# 47745   ABADAL CAB FRANC TEMPRANILLO - 750ML          WINE      0            3
# 53775   ABADAL CAB FRANC TEMPRANILLO - 750ML          WINE    170            0
# 61121   ABADAL CAB FRANC TEMPRANILLO - 750ML          WINE      0            2
# 74811   ABADAL CAB FRANC TEMPRANILLO - 750ML          WINE      0            6

# %%
data = data.groupby(['YEAR', 'MONTH', 'CONTRAGENT', 'ARTICLE_NAME',
             'ARTICLE_GROUP'])[['SALES', 'STORE_SALES']].sum().reset_index()
data.shape
# Out:
# (128013, 7)

# %% [markdown]
# Далее посмотрим какие значения принимают численные признаки.

# %%
data.describe()
# Out:
#                 YEAR          MONTH         SALES    STORE_SALES
# count  128013.000000  128013.000000  1.280130e+05  128013.000000
# mean     2017.206174       7.078844  6.580570e+03      23.077070
# std         0.404559       3.646479  2.896244e+04     237.188478
# min      2017.000000       1.000000 -6.490000e+03     -45.000000
# 25%      2017.000000       5.000000  0.000000e+00       0.000000
# 50%      2017.000000       8.000000  3.300000e+02       1.000000
# 75%      2017.000000      10.000000  3.270000e+03       4.000000
# max      2018.000000      12.000000  1.616600e+06   16271.000000

# %% [markdown]
# Создадим новый временной признак YEAR_MONTH и посмотри сколько было суммарно продаж по месяцам.
#
# Видим что у нас данные 2017-2018 года. Присуствуют отрицательные значения по продажам. Продажи фиксировались с апреля 2017 по февраль 2018, при этом есть пропуск записей в июле 2017, а в апреле 2017 исключительно нулевые продажи. Для обучения моделей не будем использовать этот месяц.

# %% [markdown]
# По графику суммарных продаж, видим что пик приходится на декабрь 2017 года, что, вероятно, связано с праздниками.

# %%
data['YEAR_MONTH'] = data["YEAR"].astype('str') + '_' \
                     + data["MONTH"].astype('str').apply(lambda x: x.zfill(2))
    
data.sort_values('YEAR_MONTH', inplace=True)

y = data.groupby('YEAR_MONTH')['SALES'].sum()
x = [0, 1, 2, 4, 5, 6, 7, 8, 9, 10]
x_inds = list(y.index)
x_inds.append('2017_07')
x_inds.sort()
y_inds = [str(x)+' млн.' for x in range(0, 140, 20)]

plt.plot(x, y, marker='o', linewidth=2, markersize=12)
plt.xticks(range(11), x_inds)
plt.yticks([x*1e6 for x in range(0, 140, 20)], y_inds)
plt.grid(True)
plt.title('Суммарные продажи SALES по месяцам');

# %% [markdown]
# Узнаем как много нулевых и отрицательных значений по продажам. Возможно отрицательные несут какой-то физический смысл (разбитые партии, ошибки). Нулевых значений SALES 38%.

# %%
print('Нулевых значений SALES {:.2f}%'.format(100*data[data.SALES == 0].shape[0]/len(data)))
print('Отрицательных значений SALES {:.2f}%'.format(100*data[data.SALES < 0].shape[0]/len(data)))
data[data.SALES < 0]
# Out:
# Нулевых значений SALES 38.23%
# Отрицательных значений SALES 0.04%
#         YEAR  MONTH                         CONTRAGENT  \
# 6718    2017      5              BACCHUS IMPORTERS LTD
# 6755    2017      5              BACCHUS IMPORTERS LTD
# 7636    2017      5                CAMPARI AMERICA LLC
# 8528    2017      5          DELICATO FAMILY VINEYARDS
# 12637   2017      5                            MHW LTD
# 13835   2017      5            PARK STREET IMPORTS LLC
# 14210   2017      5  PRESTIGE BEVERAGE GROUP OF MD LLC
# 19428   2017      6              A VINTNERS SELECTIONS
# 22227   2017      6           DIAGEO NORTH AMERICA INC
# 22233   2017      6           DIAGEO NORTH AMERICA INC
# 23123   2017      6              DUCKHORN WINE COMPANY
# 24766   2017      6                 JIM BEAM BRANDS CO
# 25235   2017      6            KYSELA PERE ET FILS LTD
# 26397   2017      6                            MHW LTD
# 28991   2017      6  REPUBLIC NATIONAL DISTRIBUTING CO
# 29980   2017      6                    ROYAL WINE CORP
# 30571   2017      6  SOUTHERN GLAZERS WINE AND SPIRITS
# 35067   2017      8              CONSTANTINE WINES INC
# 38179   2017      8     JACKSON FAMILY ENTERPRISES INC
# 42893   2017      8  REPUBLIC NATIONAL DISTRIBUTING CO
# 43469   2017      8  REPUBLIC NATIONAL DISTRIBUTING CO
# 46204   2017      9              A VINTNERS SELECTIONS
# 50914   2017      9                   FETZER VINEYARDS
# 56215   2017      9  REPUBLIC NATIONAL DISTRIBUTING CO
# 57712   2017      9  SOUTHERN GLAZERS WINE AND SPIRITS
# 58361   2017      9                  TREANA WINERY LLC
# 58636   2017      9                    TRI-VIN IMPORTS
# 66829   2017     10                MASS BAY BREWING CO
# 72706   2017     11              A VINTNERS SELECTIONS
# 72729   2017     11              A VINTNERS SELECTIONS
# 73386   2017     11              A VINTNERS SELECTIONS
# 76395   2017     11      DEUTSCH FAMILY WINE & SPIRITS
# 78807   2017     11       HEAVEN HILL DISTILLERIES INC
# 79942   2017     11          LANTERNA DISTRIBUTORS INC
# 81211   2017     11                  MOET HENNESSY USA
# 81999   2017     11    OPICI FAMILY DISTRIBUTING OF MD
# 82272   2017     11                PATERNO IMPORTS LTD
# 82815   2017     11                PROXIMO SPIRITS INC
# 83773   2017     11  REPUBLIC NATIONAL DISTRIBUTING CO
# 94379   2017     12          LANTERNA DISTRIBUTORS INC
# 99789   2017     12  SOUTHERN GLAZERS WINE AND SPIRITS
# 101586  2017     12              YOUNG WON TRADING INC
# 101841  2018      1              A VINTNERS SELECTIONS
# 104186  2018      1         CHARLES JACQUIN ET CIE INC
# 108451  2018      1                        LEGENDS LTD
# 109025  2018      1                     LUNEAU USA INC
# 109193  2018      1                            MHW LTD
# 111198  2018      1                 QUINTESSENTIAL LLC
# 113773  2018      1             SUTTER HOME WINERY INC
# 118342  2018      2           DIAGEO NORTH AMERICA INC
# 118880  2018      2               DMV DISTRIBUTING LLC
# 120809  2018      2                 JIM BEAM BRANDS CO
# 121977  2018      2                        LEGENDS LTD
# 124937  2018      2  REPUBLIC NATIONAL DISTRIBUTING CO
# 126536  2018      2  SOUTHERN GLAZERS WINE AND SPIRITS
#
#                                              ARTICLE_NAME ARTICLE_GROUP  \
# 6718                      CLEAR CREEK S/M WHISKEY - 750ML        LIQUOR
# 6755             DOM CICCIO AND FIGLI FINOCCHIETO - 750ML        LIQUOR
# 7636                           GRAND MARNIER 1880 - 750ML        LIQUOR
# 8528                     MASSIMO NEW ZELAND S/BLC - 750ML          WINE
# 12637                   BOL'S CREME DE MINT WHITE - 750ML        LIQUOR
# 13835                     TANTEO CHIPOTLE TEQUILA - 750ML        LIQUOR
# 14210                CATOCTIN CREEK MOSBYS SPIRIT - 750ML        LIQUOR
# 19428                               STONEWALL RUM - 750ML        LIQUOR
# 22227                  CROWN ROYAL XTRA RARE 6/CS - 750ML        LIQUOR
# 22233         DON JULIO TEQUILA - 70TH ANIVERSARY - 750ML        LIQUOR
# 23123                        DUCKHORN NAPA MER 12 - 750ML          WINE
# 24766               DEKUYPER SIGN VANILLA DELIGHT - 750ML        LIQUOR
# 25235                              KEERMONT RED BLEND '12          WINE
# 26397                FEUDI D'ALBE MONTEPUL D'ABRU - 750ML          WINE
# 28991                        BRANCOTT MARL P/NOIR - 750ML          WINE
# 29980                         BARON HERZOG P/GRIG - 750ML          WINE
# 30571                         LEGENDE BORDEAUX RG - 750ML          WINE
# 35067                 WHITEHALL LANE NAPA VLY MER - 750ML          WINE
# 38179                   K JACKSON AVANT RED BLEND - 750ML          WINE
# 42893                 KAVALAN SINGLE MALT WHISKEY - 750ML        LIQUOR
# 43469                               ZACA MESA SYR - 750ML          WINE
# 46204                        HUM BOTANICAL SPIRIT - 750ML        LIQUOR
# 50914                                 JEKEL CHARD - 750ML          WINE
# 56215                           JEAN MARC XO VODKA -750ML        LIQUOR
# 57712                              TY KU CUCUMBER - 720ML          WINE
# 58361                                  TREANA RED - 750ML          WINE
# 58636                                WEREWOLF CAB - 750ML          WINE
# 66829                          HARPOON IPA 2/12 NR - 12OZ          BEER
# 72706                            ANGELINE RES MER - 750ML          WINE
# 72729                            ARGIOLAS TURRIGA - 750ML          WINE
# 73386                  PAUL HOBBS CROSSBARN CHARD - 750ML          WINE
# 76395                        BIB & TUCKER BOURBON - 750ML        LIQUOR
# 78807                PARKERS HERITAGE COLLECTION  - 750ML        LIQUOR
# 79942               DOM DE LA COLLONGE POU/FUISSE - 750ML          WINE
# 81211                       KRUG GRAND CUVEE 6/CS - 750ML          WINE
# 81999                    GLENCADAM 13YR SM SCOTCH - 750ML        LIQUOR
# 82272               SANFORD SANTA RITA HILLS CHARD -750ML          WINE
# 82815          1800 SILVER TEQUILA - W/SHOT GLASS - 750ML        LIQUOR
# 83773                         BOOTLEGGER 21 VODKA - 750ML        LIQUOR
# 94379                      CASSINELLI JEN'S VODKA - 750ML        LIQUOR
# 99789                                DAOU RES CAB - 750ML          WINE
# 101586               SHO CHUKU BAI MIO SPARK SAKE - 300ML          WINE
# 101841                  CH PEYRAUD COTES DE BLAYE - 750ML          WINE
# 104186                 PENNSYLVANIA DUTCH EGG NOG - 750ML        LIQUOR
# 108451  BALTIMORE BEER WORKS ANNABEL LEE WHITE 4/6 12....          BEER
# 109025                    CH MAGENCE WHITE GRAVES - 750ML          WINE
# 109193           CH DE LARDILEY CAB/ROSE - ORGANIC -750ML          WINE
# 111198                                   ELSA CAB - 750ML          WINE
# 113773                          JARGON PINOT NOIR - 750ML          WINE
# 118342             BAILEY'S IRISH CREAM W/GLASSES - 750ML        LIQUOR
# 118880                         BON APPETIT MUSCAT - 750ML          WINE
# 120809                    COURVOISIER GOLD COGNAC - 750ML        LIQUOR
# 121977               OMMEGANG 20TH ANNIVERSARY GIFT 3/25Z          BEER
# 124937                   CARMEL ROAD DREW'S BLEND - 750ML          WINE
# 126536       MARCHESI DI BAROLO BAROLO      31343 - 750ML          WINE
#
#         SALES  STORE_SALES YEAR_MONTH
# 6718      -80            0    2017_05
# 6755     -170            0    2017_05
# 7636     -160            0    2017_05
# 8528      -80            0    2017_05
# 12637     -80            0    2017_05
# 13835   -1000            0    2017_05
# 14210   -1000            0    2017_05
# 19428   -1840            0    2017_06
# 22227   -2470            0    2017_06
# 22233    -160            0    2017_06
# 23123     -80            0    2017_06
# 24766     -10            0    2017_06
# 25235   -6490            0    2017_06
# 26397    -770           15    2017_06
# 28991    -250            0    2017_06
# 29980    -410            0    2017_06
# 30571    -430            0    2017_06
# 35067    -250            0    2017_08
# 38179   -2000            0    2017_08
# 42893    -170            0    2017_08
# 43469     -80            0    2017_08
# 46204    -160            1    2017_09
# 50914     -80            0    2017_09
# 56215    -170            0    2017_09
# 57712    -160            1    2017_09
# 58361     -80            0    2017_09
# 58636    -830            4    2017_09
# 66829    -130           11    2017_10
# 72706   -1000           15    2017_11
# 72729    -330            0    2017_11
# 73386    -170            1    2017_11
# 76395   -1000            0    2017_11
# 78807   -1990            0    2017_11
# 79942     -10            3    2017_11
# 81211    -170            0    2017_11
# 81999    -330            0    2017_11
# 82272   -1490            0    2017_11
# 82815    -170            0    2017_11
# 83773    -170            0    2017_11
# 94379     -90            0    2017_12
# 99789    -170            1    2017_12
# 101586   -420            1    2017_12
# 101841   -170            1    2018_01
# 104186    -10            0    2018_01
# 108451    -90           16    2018_01
# 109025   -250            0    2018_01
# 109193    -80            0    2018_01
# 111198   -580            2    2018_01
# 113773    -80            6    2018_01
# 118342   -170            0    2018_02
# 118880   -580            1    2018_02
# 120809    -10            0    2018_02
# 121977   -110            0    2018_02
# 124937    -80            0    2018_02
# 126536   -250            0    2018_02

# %%
print('Нулевых значений STORE_SALES {:.2f}%'.format(100*data[data.STORE_SALES == 0].shape[0]/len(data)))
print('Отрицательных значений STORE_SALES {:.2}%'.format(100*data[data.STORE_SALES < 0].shape[0]/len(data)))
data[data.STORE_SALES < 0]
# Out:
# Нулевых значений STORE_SALES 38.67%
# Отрицательных значений STORE_SALES 0.18%
#         YEAR  MONTH                CONTRAGENT  \
# 5388    2017      5     A VINTNERS SELECTIONS
# 7886    2017      5     CONSTANTINE WINES INC
# 7952    2017      5     CONSTANTINE WINES INC
# 7960    2017      5     CONSTANTINE WINES INC
# 10689   2017      5  GROTH VINEYARDS & WINERY
# ...      ...    ...                       ...
# 126898  2018      2    SUTTER HOME WINERY INC
# 126901  2018      2    SUTTER HOME WINERY INC
# 126973  2018      2    SUTTER HOME WINERY INC
# 127750  2018      2   WAGNER WINE COMPANY LLC
# 127793  2018      2          WASHBURN WINE CO
#
#                                              ARTICLE_NAME ARTICLE_GROUP  \
# 5388              CARLOS SERRES VIURA TEMP BLANCO - 750ML          WINE
# 7886                               AXIOS CAB 6/CS - 750ML          WINE
# 7952                              FREY BIODYNAMIC - 750ML          WINE
# 7960                                  FUSE CAB 13 - 750ML          WINE
# 10689                                   GROTH CAB - 750ML          WINE
# ...                                                   ...           ...
# 126898                        CARMEN GRAN RES CAB - 750ML          WINE
# 126901               CHARLES AND CHARLES RIESLING - 750ML          WINE
# 126973                         SYCAMORE LANE CHARD - 1.5L          WINE
# 127750  CAYMUS SPECIAL SELECTION CABERNET SAUVIGNON '1...          WINE
# 127793            SILLY ENGHIEN NOEL TRIPLE BLONDE - 1/6K          KEGS
#
#         SALES  STORE_SALES YEAR_MONTH
# 5388        0           -2    2017_05
# 7886        0           -1    2017_05
# 7952        0           -1    2017_05
# 7960        0           -1    2017_05
# 10689     900           -1    2017_05
# ...       ...          ...        ...
# 126898      0           -1    2018_02
# 126901    560           -1    2018_02
# 126973    660           -7    2018_02
# 127750   3000           -2    2018_02
# 127793      0           -1    2018_02
#
# [232 rows x 8 columns]

# %% [markdown]
# Посмотрим какие значения принимают категориальные признаки.

# %%
data.describe(include=['object'])
# Out:
#                                CONTRAGENT                       ARTICLE_NAME  \
# count                              128013                             128013
# unique                                333                              23413
# top     REPUBLIC NATIONAL DISTRIBUTING CO  DONA PAULA LOS CARDOS MAL - 750ML
# freq                                 9820                                 17
#
#        ARTICLE_GROUP YEAR_MONTH
# count         128013     128013
# unique             7         10
# top             WINE    2017_11
# freq           78801      14495

# %%
print('Top-10 CONTRAGENT (наиболее часто встречаются в данных):')
100*data['CONTRAGENT'].value_counts(normalize=True, sort=True)[:10]
# Out:
# Top-10 CONTRAGENT (наиболее часто встречаются в данных):
# REPUBLIC NATIONAL DISTRIBUTING CO    7.671096
# A VINTNERS SELECTIONS                6.739940
# LEGENDS LTD                          4.290970
# SOUTHERN GLAZERS WINE AND SPIRITS    3.672283
# E & J GALLO WINERY                   3.647286
# BACCHUS IMPORTERS LTD                3.408248
# MONSIEUR TOUTON SELECTION            3.312164
# DIAGEO NORTH AMERICA INC             2.603642
# RELIABLE CHURCHILL LLLP              2.231805
# CONSTELLATION BRANDS                 2.227118
# Name: CONTRAGENT, dtype: float64

# %%
print('Top-10 CONTRAGENT (по продажам):')
top_agents = data.groupby('CONTRAGENT')['SALES'].sum().sort_values(ascending=False)[:10]
top_agents
# Out:
# Top-10 CONTRAGENT (по продажам):
# CONTRAGENT
# E & J GALLO WINERY          67455608
# DIAGEO NORTH AMERICA INC    57656357
# CONSTELLATION BRANDS        54472496
# ANHEUSER BUSCH INC          42559140
# JIM BEAM BRANDS CO          39156784
# MILLER BREWING COMPANY      35022630
# BACARDI USA INC             28034626
# CROWN IMPORTS               26707830
# SAZERAC CO                  25772623
# THE WINE GROUP              25758147
# Name: SALES, dtype: int64

# %%
fig, ax = plt.subplots()
y_inds = [str(x)+' млн.' for x in range(0, 12, 2)]
sns.lineplot(x="YEAR_MONTH", y="SALES", hue="CONTRAGENT", 
             ci=None, estimator="sum", marker='o', linewidth=2, markersize=12,
             ax=ax, data=data[data['CONTRAGENT'].isin(top_agents.index)])
plt.yticks([x*1e6 for x in range(0, 12, 2)], y_inds)
plt.legend(fontsize=8)
plt.grid(True)
plt.title('Суммарные продажи по CONTRAGENT');

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.lineplot(x="YEAR_MONTH", y="SALES", hue="CONTRAGENT",  
             ci=95, estimator="mean", marker='o', linewidth=2, markersize=12,
             ax = ax, data=data[data['CONTRAGENT'].isin(top_agents.index)])
plt.legend(fontsize=8)
plt.grid(True)
plt.title('Средние продажи по CONTRAGENT');

# %% [markdown]
# Из графика видно, что у компании "CROWN IMPPORTS" большой разброс продаж.

# %%
data['ARTICLE_GROUP'].value_counts(normalize=True)
# Out:
# WINE            0.615570
# LIQUOR          0.221720
# BEER            0.128292
# KEGS            0.028411
# NON-ALCOHOL     0.004906
# STR_SUPPLIES    0.000828
# REF             0.000273
# Name: ARTICLE_GROUP, dtype: float64

# %%
sns.lmplot('STORE_SALES', 'SALES', data=data, hue='ARTICLE_GROUP', 
           hue_order=['LIQUOR','BEER','WINE','NON-ALCOHOL','KEGS','REF'],
           palette="Set1", aspect=2, fit_reg=False)
plt.title('Продажи по категориям');

# %% [markdown]
# По графику видно, что продажи товаров различаются в зависимости от категорий: для BEER в среднем характерно большее значение STORE_SALES, в то время как для WINE и LIQUOR оно ближе к нулю. Для категорий KEGS, DUNNAGE, REF значения SALES близки к нулю и в среднем меньше чем для других категорий.

# %%
def conf_interval(vals):
    v_std = vals.std(ddof=1)/np.sqrt(len(vals))
    interval = _tconfint_generic(vals.mean(), v_std, len(vals) - 1, 0.05, 'two-sided')
    return [round(x,2) for x in interval]

data.groupby(['ARTICLE_GROUP'])['SALES','STORE_SALES'].agg([np.mean,
                    np.std, conf_interval]).sort_values(by=('SALES','mean'), ascending=False)
# Out:
# <ipython-input-44-eb3d3075807c>:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['ARTICLE_GROUP'])['SALES','STORE_SALES'].agg([np.mean,
#                       SALES                                     STORE_SALES  \
#                        mean           std         conf_interval        mean
# ARTICLE_GROUP
# NON-ALCOHOL    12913.964968  28601.579886  [10672.68, 15155.25]   13.764331
# BEER           12772.520368  56836.382416   [11903.2, 13641.84]  148.355903
# LIQUOR         10916.668604  35949.534338  [10498.42, 11334.91]    1.166755
# STR_SUPPLIES    9396.037736  38724.369433   [1938.19, 16853.89]    0.000000
# REF             8038.285714   9573.052708   [4749.83, 11326.74]    0.000000
# WINE            3977.111090  13840.850732    [3880.47, 4073.75]    5.487215
# KEGS               0.000000      0.000000            [0.0, 0.0]   11.976354
#
#
#                       std     conf_interval
# ARTICLE_GROUP
# NON-ALCOHOL     39.511392    [10.67, 16.86]
# BEER           646.936397  [138.46, 158.25]
# LIQUOR           7.787950      [1.08, 1.26]
# STR_SUPPLIES     0.000000        [0.0, 0.0]
# REF              0.000000        [0.0, 0.0]
# WINE            16.836309       [5.37, 5.6]
# KEGS            44.882152    [10.52, 13.44]

# %%
fig, ax = plt.subplots()
y_inds = [str(x)+' млн.' for x in range(0, 60, 10)]
sns.lineplot(x="YEAR_MONTH", y="SALES", hue="ARTICLE_GROUP", 
             ci=None, estimator="sum", marker='o', linewidth=2, markersize=12,
             ax=ax, data=data)
plt.yticks([x*1e6 for x in range(0, 60, 10)], y_inds)
plt.legend(fontsize=8)
plt.grid(True)
plt.title('Суммарные продажи по категориям');

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.lineplot(x="YEAR_MONTH", y="SALES", hue="ARTICLE_GROUP",  
             ci=95, estimator="mean", marker='o', linewidth=2, markersize=12,
             ax = ax, data=data)
plt.legend(fontsize=8)
plt.grid(True)
plt.title('Средние продажи по категориям');

# %%
print('Top-10 ARTICLE_NAME (наиболее часто встречаются в данных):')
top_codes = data['ARTICLE_NAME'].value_counts(normalize=False, sort=True)
print(top_codes)
plt.figure(figsize = (8,4))
sns.histplot(top_codes, bins=17)
plt.title('Как часто упоминаются одинаковые товары', fontsize=14)
plt.xlabel('кол-во записей о товаре',fontsize=14)
plt.ylabel('кол-во товаров', fontsize=14)
plt.xticks(range(1,18),fontsize=14)
plt.yticks(fontsize=14);
# Out:
# Top-10 ARTICLE_NAME (наиболее часто встречаются в данных):
# DONA PAULA LOS CARDOS MAL - 750ML       17
# SUN GARDEN RIES - 750ML                 13
# LA CREMA CARNEROS P/NOIR - 750ML        12
# ROSATELLO MOSCATO - 750ML               11
# STORYPOINT CHARD  - 750ML               10
#                                         ..
# CH LYONNAT - 750ML                       1
# DOM CROIX BELLE CHAMP DU LYS - 750ML     1
# ST BERNARDUS ABT 12 NR 4/CS - 1.5L       1
# MILLER HIGH LIFE LT 2/12 LNNR - 12OZ     1
# LAMBERT EST SWEET JANE RIES - 750ML      1
# Name: ARTICLE_NAME, Length: 23413, dtype: int64

# %% [markdown]
# Видим что даже для наиболее часто встречающихся в данных товаров число записей не больше 17. Посмотрим что за товары встречаются от 11 до 17 раз. Заметим, что частота их упоминаний больше чем количество месяцев (10) из-за того что их реализуют разные CONTRAGENT.

# %%
top_codes[top_codes > 10]
# Out:
# DONA PAULA LOS CARDOS MAL - 750ML    17
# SUN GARDEN RIES - 750ML              13
# LA CREMA CARNEROS P/NOIR - 750ML     12
# ROSATELLO MOSCATO - 750ML            11
# Name: ARTICLE_NAME, dtype: int64

# %%
data[data['ARTICLE_NAME'].isin(top_codes[top_codes > 10].index)
    ].sort_values(['ARTICLE_NAME','YEAR_MONTH'])[:20]
# Out:
#         YEAR  MONTH                         CONTRAGENT  \
# 4638    2017      4             SUTTER HOME WINERY INC
# 15465   2017      5  REPUBLIC NATIONAL DISTRIBUTING CO
# 17385   2017      5             SUTTER HOME WINERY INC
# 29154   2017      6  REPUBLIC NATIONAL DISTRIBUTING CO
# 30987   2017      6             SUTTER HOME WINERY INC
# 42716   2017      8  REPUBLIC NATIONAL DISTRIBUTING CO
# 44563   2017      8             SUTTER HOME WINERY INC
# 57934   2017      9             SUTTER HOME WINERY INC
# 69673   2017     10  REPUBLIC NATIONAL DISTRIBUTING CO
# 71507   2017     10             SUTTER HOME WINERY INC
# 83973   2017     11  REPUBLIC NATIONAL DISTRIBUTING CO
# 85949   2017     11             SUTTER HOME WINERY INC
# 98330   2017     12  REPUBLIC NATIONAL DISTRIBUTING CO
# 100383  2017     12             SUTTER HOME WINERY INC
# 111911  2018      1  REPUBLIC NATIONAL DISTRIBUTING CO
# 113768  2018      1             SUTTER HOME WINERY INC
# 126904  2018      2             SUTTER HOME WINERY INC
# 3997    2017      4  REPUBLIC NATIONAL DISTRIBUTING CO
# 15667   2017      5  REPUBLIC NATIONAL DISTRIBUTING CO
# 29374   2017      6  REPUBLIC NATIONAL DISTRIBUTING CO
#
#                              ARTICLE_NAME ARTICLE_GROUP  SALES  STORE_SALES  \
# 4638    DONA PAULA LOS CARDOS MAL - 750ML          WINE      0            0
# 15465   DONA PAULA LOS CARDOS MAL - 750ML          WINE   1680            0
# 17385   DONA PAULA LOS CARDOS MAL - 750ML          WINE    820           18
# 29154   DONA PAULA LOS CARDOS MAL - 750ML          WINE   3930            0
# 30987   DONA PAULA LOS CARDOS MAL - 750ML          WINE    500           20
# 42716   DONA PAULA LOS CARDOS MAL - 750ML          WINE    160            0
# 44563   DONA PAULA LOS CARDOS MAL - 750ML          WINE   2040           12
# 57934   DONA PAULA LOS CARDOS MAL - 750ML          WINE   3500            7
# 69673   DONA PAULA LOS CARDOS MAL - 750ML          WINE     80            0
# 71507   DONA PAULA LOS CARDOS MAL - 750ML          WINE   1540           22
# 83973   DONA PAULA LOS CARDOS MAL - 750ML          WINE    650            0
# 85949   DONA PAULA LOS CARDOS MAL - 750ML          WINE   8840           31
# 98330   DONA PAULA LOS CARDOS MAL - 750ML          WINE    570            0
# 100383  DONA PAULA LOS CARDOS MAL - 750ML          WINE   2150           13
# 111911  DONA PAULA LOS CARDOS MAL - 750ML          WINE    250            0
# 113768  DONA PAULA LOS CARDOS MAL - 750ML          WINE      0           25
# 126904  DONA PAULA LOS CARDOS MAL - 750ML          WINE      0           17
# 3997     LA CREMA CARNEROS P/NOIR - 750ML          WINE      0            0
# 15667    LA CREMA CARNEROS P/NOIR - 750ML          WINE    670            8
# 29374    LA CREMA CARNEROS P/NOIR - 750ML          WINE   1860            9
#
#        YEAR_MONTH
# 4638      2017_04
# 15465     2017_05
# 17385     2017_05
# 29154     2017_06
# 30987     2017_06
# 42716     2017_08
# 44563     2017_08
# 57934     2017_09
# 69673     2017_10
# 71507     2017_10
# 83973     2017_11
# 85949     2017_11
# 98330     2017_12
# 100383    2017_12
# 111911    2018_01
# 113768    2018_01
# 126904    2018_02
# 3997      2017_04
# 15667     2017_05
# 29374     2017_06

# %%
fig, ax = plt.subplots()
y_inds = [str(x)+' млн.' for x in range(0, 60, 10)]
sns.lineplot(x="YEAR_MONTH", y="SALES", hue="ARTICLE_NAME", 
             ci=None, estimator="sum", marker='o', linewidth=2, markersize=12,
             ax=ax, data=data[data['ARTICLE_NAME'].isin(top_codes[:10].index)])
plt.legend(fontsize=6)
plt.grid(True)
plt.title('Суммарные продажи наиболее популярных товаров');

# %%
data.loc[data['YEAR_MONTH'] == '2017_04',['SALES','STORE_SALES']].sum()
# Out:
# SALES          0
# STORE_SALES    0
# dtype: int64
